# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([1,2,3,4,5,6])
y = np.array([2,4,6,8,10, 12])

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(y)
plt.show()

# %%
n2 = np.array([1,2,3,4,5])
plt.plot(n2, linestyle = 'dotted')

# %%
n2 = np.array([1,2,3,4,5])
plt.plot(n2, linestyle = 'dashed')

# %%
x = np.array([1,2,3,4,5])
y = np.array(['a','b','c','d','e'])

# %%
plt.bar(y,x)
# Out:
# <BarContainer object of 5 artists>

# %%
x = np.array([1,2,3,4,5,6])
y = np.array([2,4,6,8,10, 12])

# %%
plt.scatter(x,y)

# %%
x = np.array([1,2,3,4,5])

# %%
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x24d47d80810>,
#   <matplotlib.patches.Wedge at 0x24d4a428ed0>,
#   <matplotlib.patches.Wedge at 0x24d4a429dd0>,
#   <matplotlib.patches.Wedge at 0x24d4a42a910>,
#   <matplotlib.patches.Wedge at 0x24d4a42b890>],
#  [Text(1.075962358309037, 0.22870287165240302, ''),
#   Text(0.7360436312779136, 0.817459340184711, ''),
#   Text(-0.33991877217145816, 1.046162142464278, ''),
#   Text(-1.0759623315431446, -0.2287029975759841, ''),
#   Text(0.5500001932481627, -0.9526278325909777, '')])

# %%
x = np.random.normal(10,20,30)
plt.hist(x)
# Out:
# (array([1., 1., 0., 1., 2., 6., 8., 5., 5., 1.]),
#  array([-54.70549471, -45.30171588, -35.89793705, -26.49415822,
#         -17.09037939,  -7.68660056,   1.71717828,  11.12095711,
#          20.52473594,  29.92851477,  39.3322936 ]),
#  <BarContainer object of 10 artists>)
